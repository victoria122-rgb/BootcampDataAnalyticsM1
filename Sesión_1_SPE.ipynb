# %% [markdown]
# # **Bootcamp Data Analytics for Oil & Gas**

# %%
pozo = "SPE-001"

# %%
pozo
# Out:
# 'SPE-001'

# %%
petroleo_bpd = 1250

# %%
petroleo_bpd
# Out:
# 1250

# %%
agua_bpd = 350.50

# %%
agua_bpd
# Out:
# 350.5

# %%
status = True

# %%
status
# Out:
# True

# %%
liquido_total_bpd = petroleo_bpd + agua_bpd

# %%
liquido_total_bpd
# Out:
# 1600.5

# %%
corte_agua_pct = (agua_bpd / liquido_total_bpd) * 100

# %%
corte_agua_pct
# Out:
# 21.89940643548891

# %% [markdown]
# # **Sección 1**

# %%
print("El nombre del pozo es", pozo)
# Out:
# El nombre del pozo es SPE-001

# %% [markdown]
# # **Sección 2**

# %% [markdown]
# # **Sección 3**
